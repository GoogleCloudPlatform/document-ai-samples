# %% [markdown]
# ## This notebook covers how you can leverage Form Parser to generate annotations for Document AI Workbench.
#
# Code uses Form Parser `form_fields` and convert them to `entities`.
#
# - Uses Fake W-2 Dataset from [Kaggle](https://www.kaggle.com/datasets/mcvishnu1/fake-w2-us-tax-form-dataset)
# - Originally created by @HSbedi87

# %%
# Install necessary Python libraries and restart your kernel after.
# !python -m pip install -r requirements.txt

# %%
import json
import re
import time
from typing import List

from google.api_core.client_options import ClientOptions
from google.cloud import documentai
from google.cloud import storage

# %% [markdown]
# ## Set your processor variables

# %%
PROJECT_ID = ""
LOCATION = "us"  # Format is 'us' or 'eu'

PROCESSOR_ID = ""  # Create processor in Cloud Console
GCS_INPUT_BUCKET = ""
GCS_INPUT_PREFIX = ""
GCS_OUTPUT_URI = ""
GCS_OUTPUT_URI_PREFIX = ""
GCS_OUTPUT_ANNOTATION_BUCKET = ""
GCS_OUTPUT_ANNOTATION_URI_PREFIX = ""

TIMEOUT = 360

PDF_MIME_TYPE = "application/pdf"

# %% [markdown]
# The following code calls the batch API and stores response in output GCS location.

# %%
def process_document_from_input_file():
    destination_uri = f"{GCS_OUTPUT_URI}/{GCS_OUTPUT_URI_PREFIX}/"

    client = documentai.DocumentProcessorServiceClient(
        client_options=ClientOptions(
            api_endpoint=f"{LOCATION}-documentai.googleapis.com"
        )
    )
    name = client.processor_path(
        project=PROJECT_ID, location=LOCATION, processor=PROCESSOR_ID
    )

    storage_client = storage.Client()
    bucket = storage_client.bucket(GCS_INPUT_BUCKET)
    input_configs = []
    print("Input Files:")
    counter = 0
    api_counter = 0
    documents: List[documentai.GcsDocument] = []

    def _batch_process(
        name: str,
        input_config: documentai.BatchDocumentsInputConfig,
        destination_uri: str,
    ):
        """
        Batch process documents.
        """
        output_config = documentai.DocumentOutputConfig(
            gcs_output_config=documentai.DocumentOutputConfig.GcsOutputConfig(
                gcs_uri=destination_uri
            )
        )
        request = documentai.BatchProcessRequest(
            name=name,
            input_documents=input_config,
            document_output_config=output_config,
        )
        print(input_config)
        operation = client.batch_process_documents(request)

    blobs = bucket.list_blobs(prefix=GCS_INPUT_PREFIX)

    for blob in blobs:
        counter = counter + 1
        source = f"gs://{GCS_INPUT_BUCKET}/{blob.name}"
        # print(source)

        if ".pdf" in source.lower():
            print(source)

            document = documentai.GcsDocument(gcs_uri=source, mime_type=PDF_MIME_TYPE)
            documents.append(document)

            gcs_documents = documentai.GcsDocuments(documents=documents)

            input_config = documentai.BatchDocumentsInputConfig(
                gcs_documents=gcs_documents
            )
            input_configs.append(input_config)

            if counter % 50 == 0:
                if api_counter >= 4:
                    api_counter = 0
                    time.sleep(TIMEOUT)

                _batch_process(name, input_config, destination_uri)

                print("process called")
                api_counter = api_counter + 1
                # print(output_config)

                # Wait for the operation to finish
                # operation.result(timeout=TIMEOUT)

                input_configs = []
                documents = []
                print(counter)

    if input_configs:
        _batch_process(name, input_config, destination_uri)
        print("process called out")

# %% [markdown]
# ### Step1: Call Form Parser to batch process

# %%
process_document_from_input_file()

# %%
def format_field_name(name, demiliter="_"):
    CDE_field_dict = {
        "A_EMPLOYEES_SOCIAL_SECURITY_NUMBER": "EMPL_SSN",
        "B_EMPLOYER_IDENTIFICATION_NUMBER": "EMPLR_ID_NUMBER",
        "C_EMPLOYERS_NAME_ADDRESS_AND_ZIP_CODE": "EMPLR_NAME_ADDRESS",
        "D_CONTROL_NUMBER": "CONTROL_NUMBER",
        "1_WAGES_TIPS_OTHER_COMPENSATION": "WAGES_TIPS_OTHER_COMP",
        "2_FEDERAL_INCOME_TAX_WITHHELD": "FEDERAL_INCOME_TAX_WH",
        "3_SOCIAL_SECURITY_WAGES": "SS_WAGES",
        "4_SOCIAL_SECURITY_TAX_WITHHELD": "SS_TAX_WH",
    }
    ignore_chars_list = [",", "'"]
    name = name.strip()
    name = name.upper()
    for char in ignore_chars_list:
        name = name.replace(char, "")

    split_name_str = name.split()

    cde_name = demiliter.join(split_name_str)

    if cde_name in CDE_field_dict:
        return CDE_field_dict[cde_name]
    else:
        return None


def create_entity(
    form_field_name, form_field_value, form_textSegments, form_boundingPoly
):
    entity_field_name = format_field_name(form_field_name)

    if entity_field_name:
        entity = {}
        entity["mentionText"] = form_field_value
        entity["type"] = entity_field_name

        normalizedVertices = []
        for vertex in form_boundingPoly.normalized_vertices:
            x = vertex.x
            y = vertex.y
            normalizedVertices.append({"x": x, "y": y})

        pageRefs = []
        pageRefs.append({"boundingPoly": {"normalizedVertices": normalizedVertices}})
        entity["pageAnchor"] = {"pageRefs": pageRefs}

        textSegments = []
        for segment in form_textSegments:
            textSegments.append(
                {"endIndex": segment.end_index, "startIndex": segment.start_index}
            )
        entity["textAnchor"] = {
            "content": form_field_value,
            "textSegments": textSegments,
        }

        return entity

    else:
        return None


def entity_from_formfield(form_field):
    field_name = form_field.field_name.text_anchor.content
    field_value = form_field.field_value.text_anchor.content
    boundingPoly = form_field.field_value.bounding_poly
    textSegments = form_field.field_value.text_anchor.text_segments
    entity = create_entity(field_name, field_value, textSegments, boundingPoly)
    return entity


def generate_entities_from_form_fields(document):
    entities = None
    for page in document.pages:
        for form_field in page.form_fields:
            entity = entity_from_formfield(form_field)
            # print(entity)
            if entity:
                if not entities:
                    entities = []
                entities.append(entity)
    print(entities)
    return entities


def parse_sample_files_in_gcsbucket_mod():
    destination_uri = f"{GCS_OUTPUT_URI}/{GCS_OUTPUT_URI_PREFIX}/"
    # Results are written to GCS. Use a regex to find
    # output files
    match = re.match(r"gs://([^/]+)/(.+)", destination_uri)
    output_bucket = match.group(1)
    prefix = match.group(2)

    storage_client = storage.Client()
    bucket = storage_client.get_bucket(output_bucket)
    blob_list = list(bucket.list_blobs(prefix=prefix))

    for i, blob in enumerate(blob_list):
        # If JSON file, download the contents of this blob as a bytes object.
        lineindex = -1
        if ".json" in blob.name:
            match = re.match(r"(.+)-(\d).json", blob.name.split("/")[-1])
            output_file_name = match.group(1)
            print(output_file_name)
            blob_as_bytes = blob.download_as_string()
            print("downloaded")

            document = documentai.types.Document.from_json(blob_as_bytes)
            document_json = json.loads(blob_as_bytes)
            print(f"Fetched file {i + 1}")
            entities = generate_entities_from_form_fields(document)
            document_json["entities"] = entities

            create_json(document_json, output_file_name)


def create_json(json_object, filename):
    """
    this function will create json object in
    google cloud storage
    """
    # create a blob
    storage_client = storage.Client()
    bucket = storage_client.get_bucket(GCS_OUTPUT_ANNOTATION_BUCKET)
    blob = bucket.blob
    blob = bucket.blob(GCS_OUTPUT_ANNOTATION_URI_PREFIX + filename + ".json")
    # upload the blob
    blob.upload_from_string(
        data=json.dumps(json_object), content_type="application/json"
    )
    result = filename + " upload complete"
    return {"response": result}

# %% [markdown]
# ### Step2: Read output json from Form parser to generate `Document` for Workbench.
#
# ---

# %%
parse_sample_files_in_gcsbucket_mod()
# Out:
# W2_XL_input_clean_2950
# downloaded
# Fetched file 2
# [{'mentionText': '66584.46\n', 'type': 'SS_WAGES', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5773606300354004, 'y': 0.5920879244804382}, {'x': 0.6581342220306396, 'y': 0.5920879244804382}, {'x': 0.6581342220306396, 'y': 0.6026373505592346}, {'x': 0.5773606300354004, 'y': 0.6026373505592346}]}}]}, 'textAnchor': {'content': '66584.46\n', 'textSegments': [{'endIndex': 2131, 'startIndex': 2122}]}}, {'mentionText': '56081.18\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5773606300354004, 'y': 0.565274715423584}, {'x': 0.6564277410507202, 'y': 0.565274715423584}, {'x': 0.6564277410507202, 'y': 0.5758242011070251}, {'x': 0.5773606300354004, 'y': 0.5758242011070251}]}}]}, 'textAnchor': {'content': '56081.18\n', 'textSegments': [{'endIndex': 2059, 'startIndex': 2050}]}}, {'mentionText': '5093.71\n', 'type': 'SS_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7724686861038208, 'y': 0.592527449131012}, {'x': 0.8435722589492798, 'y': 0.592527449131012}, {'x': 0.8435722589492798, 'y': 0.6026373505592346}, {'x': 0.7724686861038208, 'y': 0.6026373505592346}]}}]}, 'textAnchor': {'content': '5093.71\n', 'textSegments': [{'endIndex': 2139, 'startIndex': 2131}]}}, {'mentionText': '19127.2\n', 'type': 'FEDERAL_INCOME_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7730375528335571, 'y': 0.565274715423584}, {'x': 0.8424345850944519, 'y': 0.565274715423584}, {'x': 0.8424345850944519, 'y': 0.5758242011070251}, {'x': 0.7730375528335571, 'y': 0.5758242011070251}]}}]}, 'textAnchor': {'content': '19127.2\n', 'textSegments': [{'endIndex': 2067, 'startIndex': 2059}]}}, {'mentionText': '714-32-2105\n', 'type': 'EMPL_SSN', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.27303755283355713, 'y': 0.06681318581104279}, {'x': 0.38168373703956604, 'y': 0.06681318581104279}, {'x': 0.38168373703956604, 'y': 0.07692307978868484}, {'x': 0.27303755283355713, 'y': 0.07692307978868484}]}}]}, 'textAnchor': {'content': '714-32-2105\n', 'textSegments': [{'endIndex': 198, 'startIndex': 186}]}}, {'mentionText': '714-32-2105\n', 'type': 'EMPL_SSN', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.27189987897872925, 'y': 0.5375823974609375}, {'x': 0.3811149001121521, 'y': 0.5375823974609375}, {'x': 0.3811149001121521, 'y': 0.5481318831443787}, {'x': 0.27189987897872925, 'y': 0.5481318831443787}]}}]}, 'textAnchor': {'content': '714-32-2105\n', 'textSegments': [{'endIndex': 1629, 'startIndex': 1617}]}}, {'mentionText': '56081.18\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5773606300354004, 'y': 0.09318681061267853}, {'x': 0.6575654149055481, 'y': 0.09318681061267853}, {'x': 0.6575654149055481, 'y': 0.10417582094669342}, {'x': 0.5773606300354004, 'y': 0.10417582094669342}]}}]}, 'textAnchor': {'content': '56081.18\n', 'textSegments': [{'endIndex': 370, 'startIndex': 361}]}}, {'mentionText': '5093.71\n', 'type': 'SS_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7724686861038208, 'y': 0.12219779938459396}, {'x': 0.8424345850944519, 'y': 0.12219779938459396}, {'x': 0.8424345850944519, 'y': 0.13230769336223602}, {'x': 0.7724686861038208, 'y': 0.13230769336223602}]}}]}, 'textAnchor': {'content': '5093.71\n', 'textSegments': [{'endIndex': 535, 'startIndex': 527}]}}, {'mentionText': '19127.2\n', 'type': 'FEDERAL_INCOME_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7724686861038208, 'y': 0.09362637251615524}, {'x': 0.8424345850944519, 'y': 0.09362637251615524}, {'x': 0.8424345850944519, 'y': 0.10417582094669342}, {'x': 0.7724686861038208, 'y': 0.10417582094669342}]}}]}, 'textAnchor': {'content': '19127.2\n', 'textSegments': [{'endIndex': 496, 'startIndex': 488}]}}, {'mentionText': '66584.46\n', 'type': 'SS_WAG ...
# W2_XL_input_clean_2951
# downloaded
# Fetched file 3
# [{'mentionText': '88120.85\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5767918229103088, 'y': 0.09406593441963196}, {'x': 0.6575654149055481, 'y': 0.09406593441963196}, {'x': 0.6575654149055481, 'y': 0.10461538285017014}, {'x': 0.5767918229103088, 'y': 0.10461538285017014}]}}]}, 'textAnchor': {'content': '88120.85\n', 'textSegments': [{'endIndex': 271, 'startIndex': 262}]}}, {'mentionText': '88120.85\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5762229561805725, 'y': 0.5648351907730103}, {'x': 0.6575654149055481, 'y': 0.5648351907730103}, {'x': 0.6575654149055481, 'y': 0.5753846168518066}, {'x': 0.5762229561805725, 'y': 0.5753846168518066}]}}]}, 'textAnchor': {'content': '88120.85\n', 'textSegments': [{'endIndex': 2106, 'startIndex': 2097}]}}, {'mentionText': '81151.67\n', 'type': 'SS_WAGES', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5762229561805725, 'y': 0.5929670333862305}, {'x': 0.6581342220306396, 'y': 0.5929670333862305}, {'x': 0.6581342220306396, 'y': 0.6026373505592346}, {'x': 0.5762229561805725, 'y': 0.6026373505592346}]}}]}, 'textAnchor': {'content': '81151.67\n', 'textSegments': [{'endIndex': 2179, 'startIndex': 2170}]}}, {'mentionText': '6208.1\n', 'type': 'SS_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7736063599586487, 'y': 0.5929670333862305}, {'x': 0.8327645063400269, 'y': 0.5929670333862305}, {'x': 0.8327645063400269, 'y': 0.6035164594650269}, {'x': 0.7736063599586487, 'y': 0.6035164594650269}]}}]}, 'textAnchor': {'content': '6208.1\n', 'textSegments': [{'endIndex': 2186, 'startIndex': 2179}]}}, {'mentionText': '17492.09\n', 'type': 'FEDERAL_INCOME_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7724686861038208, 'y': 0.565274715423584}, {'x': 0.8538111448287964, 'y': 0.565274715423584}, {'x': 0.8538111448287964, 'y': 0.5758242011070251}, {'x': 0.7724686861038208, 'y': 0.5758242011070251}]}}]}, 'textAnchor': {'content': '17492.09\n', 'textSegments': [{'endIndex': 2115, 'startIndex': 2106}]}}, {'mentionText': 'Zimmerman, Lewis and Rhodes LLC\n2837 Craig Viaduct\nNew Bonnie NE 71650-4862\n', 'type': 'EMPLR_NAME_ADDRESS', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.08248008787631989, 'y': 0.12219779938459396}, {'x': 0.39704209566116333, 'y': 0.12219779938459396}, {'x': 0.39704209566116333, 'y': 0.16967032849788666}, {'x': 0.08248008787631989, 'y': 0.16967032849788666}]}}]}, 'textAnchor': {'content': 'Zimmerman, Lewis and Rhodes LLC\n2837 Craig Viaduct\nNew Bonnie NE 71650-4862\n', 'textSegments': [{'endIndex': 184, 'startIndex': 152}, {'endIndex': 658, 'startIndex': 614}]}}, {'mentionText': '707-30-4412\n', 'type': 'EMPL_SSN', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.27303755283355713, 'y': 0.06681318581104279}, {'x': 0.38225257396698, 'y': 0.06681318581104279}, {'x': 0.38225257396698, 'y': 0.07736263424158096}, {'x': 0.27303755283355713, 'y': 0.07736263424158096}]}}]}, 'textAnchor': {'content': '707-30-4412\n', 'textSegments': [{'endIndex': 67, 'startIndex': 55}]}}, {'mentionText': '707-30-4412\n', 'type': 'EMPL_SSN', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.2724687159061432, 'y': 0.5375823974609375}, {'x': 0.38282138109207153, 'y': 0.5375823974609375}, {'x': 0.38282138109207153, 'y': 0.5485714077949524}, {'x': 0.2724687159061432, 'y': 0.5485714077949524}]}}]}, 'textAnchor': {'content': '707-30-4412\n', 'textSegments': [{'endIndex': 1629, 'startIndex': 1617}]}}, {'mentionText': '6208.1\n', 'type': 'SS_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7730375528335571, 'y': 0.12263736128807068}, {'x': 0.8321956992149353, 'y': 0.12263736128807068}, {'x': 0.8321956992149353, 'y': 0.13274724781513214}, {'x': 0.7730375528335571,  ...
# W2_XL_input_clean_2960
# downloaded
# Fetched file 4
# [{'mentionText': '41662.12\n', 'type': 'SS_WAGES', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5762229561805725, 'y': 0.5920879244804382}, {'x': 0.6569966077804565, 'y': 0.5920879244804382}, {'x': 0.6569966077804565, 'y': 0.6026373505592346}, {'x': 0.5762229561805725, 'y': 0.6026373505592346}]}}]}, 'textAnchor': {'content': '41662.12\n', 'textSegments': [{'endIndex': 2106, 'startIndex': 2097}]}}, {'mentionText': '59143.54\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.575654149055481, 'y': 0.5657142996788025}, {'x': 0.6564277410507202, 'y': 0.5657142996788025}, {'x': 0.6564277410507202, 'y': 0.5758242011070251}, {'x': 0.575654149055481, 'y': 0.5758242011070251}]}}]}, 'textAnchor': {'content': '59143.54\n', 'textSegments': [{'endIndex': 2033, 'startIndex': 2024}]}}, {'mentionText': '3187.15\n', 'type': 'SS_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7724686861038208, 'y': 0.592527449131012}, {'x': 0.8435722589492798, 'y': 0.592527449131012}, {'x': 0.8435722589492798, 'y': 0.6026373505592346}, {'x': 0.7724686861038208, 'y': 0.6026373505592346}]}}]}, 'textAnchor': {'content': '3187.15\n', 'textSegments': [{'endIndex': 2114, 'startIndex': 2106}]}}, {'mentionText': '328-67-9633\n', 'type': 'EMPL_SSN', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.27189987897872925, 'y': 0.06637362390756607}, {'x': 0.38282138109207153, 'y': 0.06637362390756607}, {'x': 0.38282138109207153, 'y': 0.07692307978868484}, {'x': 0.27189987897872925, 'y': 0.07692307978868484}]}}]}, 'textAnchor': {'content': '328-67-9633\n', 'textSegments': [{'endIndex': 67, 'startIndex': 55}]}}, {'mentionText': '11399.12\n', 'type': 'FEDERAL_INCOME_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7724686861038208, 'y': 0.565274715423584}, {'x': 0.8532423377037048, 'y': 0.565274715423584}, {'x': 0.8532423377037048, 'y': 0.5758242011070251}, {'x': 0.7724686861038208, 'y': 0.5758242011070251}]}}]}, 'textAnchor': {'content': '11399.12\n', 'textSegments': [{'endIndex': 2042, 'startIndex': 2033}]}}, {'mentionText': '3187.15\n', 'type': 'SS_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7736063599586487, 'y': 0.12263736128807068}, {'x': 0.8418657779693604, 'y': 0.12263736128807068}, {'x': 0.8418657779693604, 'y': 0.13274724781513214}, {'x': 0.7736063599586487, 'y': 0.13274724781513214}]}}]}, 'textAnchor': {'content': '3187.15\n', 'textSegments': [{'endIndex': 525, 'startIndex': 517}]}}, {'mentionText': '328-67-9633\n', 'type': 'EMPL_SSN', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.2724687159061432, 'y': 0.5375823974609375}, {'x': 0.38282138109207153, 'y': 0.5375823974609375}, {'x': 0.38282138109207153, 'y': 0.5485714077949524}, {'x': 0.2724687159061432, 'y': 0.5485714077949524}]}}]}, 'textAnchor': {'content': '328-67-9633\n', 'textSegments': [{'endIndex': 1601, 'startIndex': 1589}]}}, {'mentionText': '59143.54\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5762229561805725, 'y': 0.09362637251615524}, {'x': 0.6575654149055481, 'y': 0.09362637251615524}, {'x': 0.6575654149055481, 'y': 0.10417582094669342}, {'x': 0.5762229561805725, 'y': 0.10417582094669342}]}}]}, 'textAnchor': {'content': '59143.54\n', 'textSegments': [{'endIndex': 270, 'startIndex': 261}]}}, {'mentionText': '11399.12\n', 'type': 'FEDERAL_INCOME_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7724686861038208, 'y': 0.09406593441963196}, {'x': 0.8515358567237854, 'y': 0.09406593441963196}, {'x': 0.8515358567237854, 'y': 0.10461538285017014}, {'x': 0.7724686861038208, 'y': 0.10461538285017014}]}}]}, 'textAnchor': {'content': '11399.12\n', 'textSegments': [{'endIndex': 486, 'startIndex': 477}]}}, {'mentionText': 'Cooper LLC Group\n282 Jill ...
# W2_XL_input_clean_2961
# downloaded
# Fetched file 5
# [{'mentionText': '13635.24\n', 'type': 'SS_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7736063599586487, 'y': 0.5920879244804382}, {'x': 0.8526734709739685, 'y': 0.5920879244804382}, {'x': 0.8526734709739685, 'y': 0.6030769348144531}, {'x': 0.7736063599586487, 'y': 0.6030769348144531}]}}]}, 'textAnchor': {'content': '13635.24\n', 'textSegments': [{'endIndex': 2163, 'startIndex': 2154}]}}, {'mentionText': '178238.43\n', 'type': 'SS_WAGES', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5773606300354004, 'y': 0.592527449131012}, {'x': 0.6672354936599731, 'y': 0.592527449131012}, {'x': 0.6672354936599731, 'y': 0.6035164594650269}, {'x': 0.5773606300354004, 'y': 0.6035164594650269}]}}]}, 'textAnchor': {'content': '178238.43\n', 'textSegments': [{'endIndex': 2154, 'startIndex': 2144}]}}, {'mentionText': '204985.28\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5784983038902283, 'y': 0.09406593441963196}, {'x': 0.6678043007850647, 'y': 0.09406593441963196}, {'x': 0.6678043007850647, 'y': 0.10505493730306625}, {'x': 0.5784983038902283, 'y': 0.10505493730306625}]}}]}, 'textAnchor': {'content': '204985.28\n', 'textSegments': [{'endIndex': 343, 'startIndex': 333}]}}, {'mentionText': '204985.28\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5784983038902283, 'y': 0.565274715423584}, {'x': 0.6660978198051453, 'y': 0.565274715423584}, {'x': 0.6660978198051453, 'y': 0.5758242011070251}, {'x': 0.5784983038902283, 'y': 0.5758242011070251}]}}]}, 'textAnchor': {'content': '204985.28\n', 'textSegments': [{'endIndex': 2080, 'startIndex': 2070}]}}, {'mentionText': '369-11-4129\n', 'type': 'EMPL_SSN', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.27076223492622375, 'y': 0.06637362390756607}, {'x': 0.38282138109207153, 'y': 0.06637362390756607}, {'x': 0.38282138109207153, 'y': 0.07648351788520813}, {'x': 0.27076223492622375, 'y': 0.07648351788520813}]}}]}, 'textAnchor': {'content': '369-11-4129\n', 'textSegments': [{'endIndex': 152, 'startIndex': 140}]}}, {'mentionText': '67754.65\n', 'type': 'FEDERAL_INCOME_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7724686861038208, 'y': 0.565274715423584}, {'x': 0.852104663848877, 'y': 0.565274715423584}, {'x': 0.852104663848877, 'y': 0.5762637257575989}, {'x': 0.7724686861038208, 'y': 0.5762637257575989}]}}]}, 'textAnchor': {'content': '67754.65\n', 'textSegments': [{'endIndex': 2089, 'startIndex': 2080}]}}, {'mentionText': '369-11-4129\n', 'type': 'EMPL_SSN', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.2713310718536377, 'y': 0.5375823974609375}, {'x': 0.38168373703956604, 'y': 0.5375823974609375}, {'x': 0.38168373703956604, 'y': 0.5481318831443787}, {'x': 0.2713310718536377, 'y': 0.5481318831443787}]}}]}, 'textAnchor': {'content': '369-11-4129\n', 'textSegments': [{'endIndex': 1632, 'startIndex': 1620}]}}, {'mentionText': '178238.43\n', 'type': 'SS_WAGES', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5767918229103088, 'y': 0.12263736128807068}, {'x': 0.6678043007850647, 'y': 0.12263736128807068}, {'x': 0.6678043007850647, 'y': 0.13318681716918945}, {'x': 0.5767918229103088, 'y': 0.13318681716918945}]}}]}, 'textAnchor': {'content': '178238.43\n', 'textSegments': [{'endIndex': 377, 'startIndex': 367}]}}, {'mentionText': 'Smith Group LLC\n2305 Albert Terrace Suite 851\nDenisefort\nNH\n10932-6017\n', 'type': 'EMPLR_NAME_ADDRESS', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.08191126585006714, 'y': 0.5929670333862305}, {'x': 0.37940841913223267, 'y': 0.5929670333862305}, {'x': 0.37940841913223267, 'y': 0.639120876789093}, {'x': 0.08191126585006714, 'y': 0.639120876789093}]}}]}, 'textAnchor': {'content': 'Smith Group LLC\n2305 Albert Terrace Suite ...
# W2_XL_input_clean_2962
# downloaded
# Fetched file 6
# [{'mentionText': '136641.73\n', 'type': 'SS_WAGES', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5773606300354004, 'y': 0.592527449131012}, {'x': 0.6678043007850647, 'y': 0.592527449131012}, {'x': 0.6678043007850647, 'y': 0.6030769348144531}, {'x': 0.5773606300354004, 'y': 0.6030769348144531}]}}]}, 'textAnchor': {'content': '136641.73\n', 'textSegments': [{'endIndex': 2114, 'startIndex': 2104}]}}, {'mentionText': '10453.09\n', 'type': 'SS_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.774175226688385, 'y': 0.5920879244804382}, {'x': 0.8532423377037048, 'y': 0.5920879244804382}, {'x': 0.8532423377037048, 'y': 0.6030769348144531}, {'x': 0.774175226688385, 'y': 0.6030769348144531}]}}]}, 'textAnchor': {'content': '10453.09\n', 'textSegments': [{'endIndex': 2123, 'startIndex': 2114}]}}, {'mentionText': '145951.66\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5779294371604919, 'y': 0.565274715423584}, {'x': 0.668373167514801, 'y': 0.565274715423584}, {'x': 0.668373167514801, 'y': 0.5758242011070251}, {'x': 0.5779294371604919, 'y': 0.5758242011070251}]}}]}, 'textAnchor': {'content': '145951.66\n', 'textSegments': [{'endIndex': 2040, 'startIndex': 2030}]}}, {'mentionText': '145951.66\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5773606300354004, 'y': 0.09406593441963196}, {'x': 0.6678043007850647, 'y': 0.09406593441963196}, {'x': 0.6678043007850647, 'y': 0.10461538285017014}, {'x': 0.5773606300354004, 'y': 0.10461538285017014}]}}]}, 'textAnchor': {'content': '145951.66\n', 'textSegments': [{'endIndex': 345, 'startIndex': 335}]}}, {'mentionText': '003-01-4555\n', 'type': 'EMPL_SSN', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.2713310718536377, 'y': 0.06637362390756607}, {'x': 0.38225257396698, 'y': 0.06637362390756607}, {'x': 0.38225257396698, 'y': 0.07648351788520813}, {'x': 0.2713310718536377, 'y': 0.07648351788520813}]}}]}, 'textAnchor': {'content': '003-01-4555\n', 'textSegments': [{'endIndex': 152, 'startIndex': 140}]}}, {'mentionText': '10453.09\n', 'type': 'SS_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7730375528335571, 'y': 0.12263736128807068}, {'x': 0.8526734709739685, 'y': 0.12263736128807068}, {'x': 0.8526734709739685, 'y': 0.13274724781513214}, {'x': 0.7730375528335571, 'y': 0.13274724781513214}]}}]}, 'textAnchor': {'content': '10453.09\n', 'textSegments': [{'endIndex': 538, 'startIndex': 529}]}}, {'mentionText': '136641.73\n', 'type': 'SS_WAGES', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5767918229103088, 'y': 0.12263736128807068}, {'x': 0.6666666865348816, 'y': 0.12263736128807068}, {'x': 0.6666666865348816, 'y': 0.13318681716918945}, {'x': 0.5767918229103088, 'y': 0.13318681716918945}]}}]}, 'textAnchor': {'content': '136641.73\n', 'textSegments': [{'endIndex': 379, 'startIndex': 369}]}}, {'mentionText': 'Johnson-Michael PLC\n6614 Marissa Place\nPearsonside\nOK\n01746-1531\n', 'type': 'EMPLR_NAME_ADDRESS', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.08361774682998657, 'y': 0.5920879244804382}, {'x': 0.40898749232292175, 'y': 0.5920879244804382}, {'x': 0.40898749232292175, 'y': 0.639120876789093}, {'x': 0.08361774682998657, 'y': 0.639120876789093}]}}]}, 'textAnchor': {'content': 'Johnson-Michael PLC\n6614 Marissa Place\nPearsonside\nOK\n01746-1531\n', 'textSegments': [{'endIndex': 1723, 'startIndex': 1703}, {'endIndex': 2403, 'startIndex': 2358}]}}, {'mentionText': '47304.54\n', 'type': 'FEDERAL_INCOME_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7730375528335571, 'y': 0.565274715423584}, {'x': 0.8526734709739685, 'y': 0.565274715423584}, {'x': 0.8526734709739685, 'y': 0.5758242011070251}, {'x': 0.7730375528335571, 'y': 0.57582420110702 ...
# W2_XL_input_clean_2963
# downloaded
# Fetched file 7
# [{'mentionText': '175847.83\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5773606300354004, 'y': 0.5648351907730103}, {'x': 0.6689419746398926, 'y': 0.5648351907730103}, {'x': 0.6689419746398926, 'y': 0.5758242011070251}, {'x': 0.5773606300354004, 'y': 0.5758242011070251}]}}]}, 'textAnchor': {'content': '175847.83\n', 'textSegments': [{'endIndex': 2045, 'startIndex': 2035}]}}, {'mentionText': '207114.0\n', 'type': 'SS_WAGES', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5784983038902283, 'y': 0.592527449131012}, {'x': 0.6575654149055481, 'y': 0.592527449131012}, {'x': 0.6575654149055481, 'y': 0.6030769348144531}, {'x': 0.5784983038902283, 'y': 0.6030769348144531}]}}]}, 'textAnchor': {'content': '207114.0\n', 'textSegments': [{'endIndex': 2118, 'startIndex': 2109}]}}, {'mentionText': '041-56-3099\n', 'type': 'EMPL_SSN', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.2701933979988098, 'y': 0.06681318581104279}, {'x': 0.38225257396698, 'y': 0.06681318581104279}, {'x': 0.38225257396698, 'y': 0.07692307978868484}, {'x': 0.2701933979988098, 'y': 0.07692307978868484}]}}]}, 'textAnchor': {'content': '041-56-3099\n', 'textSegments': [{'endIndex': 48, 'startIndex': 36}]}}, {'mentionText': '15844.22\n', 'type': 'SS_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7736063599586487, 'y': 0.592527449131012}, {'x': 0.8526734709739685, 'y': 0.592527449131012}, {'x': 0.8526734709739685, 'y': 0.6030769348144531}, {'x': 0.7736063599586487, 'y': 0.6030769348144531}]}}]}, 'textAnchor': {'content': '15844.22\n', 'textSegments': [{'endIndex': 2127, 'startIndex': 2118}]}}, {'mentionText': '53878.35\n', 'type': 'FEDERAL_INCOME_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7724686861038208, 'y': 0.565274715423584}, {'x': 0.8532423377037048, 'y': 0.565274715423584}, {'x': 0.8532423377037048, 'y': 0.5758242011070251}, {'x': 0.7724686861038208, 'y': 0.5758242011070251}]}}]}, 'textAnchor': {'content': '53878.35\n', 'textSegments': [{'endIndex': 2054, 'startIndex': 2045}]}}, {'mentionText': '175847.83\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5762229561805725, 'y': 0.09406593441963196}, {'x': 0.6678043007850647, 'y': 0.09406593441963196}, {'x': 0.6678043007850647, 'y': 0.10417582094669342}, {'x': 0.5762229561805725, 'y': 0.10417582094669342}]}}]}, 'textAnchor': {'content': '175847.83\n', 'textSegments': [{'endIndex': 360, 'startIndex': 350}]}}, {'mentionText': '041-56-3099\n', 'type': 'EMPL_SSN', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.27076223492622375, 'y': 0.5375823974609375}, {'x': 0.38282138109207153, 'y': 0.5375823974609375}, {'x': 0.38282138109207153, 'y': 0.5481318831443787}, {'x': 0.27076223492622375, 'y': 0.5481318831443787}]}}]}, 'textAnchor': {'content': '041-56-3099\n', 'textSegments': [{'endIndex': 1609, 'startIndex': 1597}]}}, {'mentionText': '53878.35\n', 'type': 'FEDERAL_INCOME_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7724686861038208, 'y': 0.09406593441963196}, {'x': 0.852104663848877, 'y': 0.09406593441963196}, {'x': 0.852104663848877, 'y': 0.10461538285017014}, {'x': 0.7724686861038208, 'y': 0.10461538285017014}]}}]}, 'textAnchor': {'content': '53878.35\n', 'textSegments': [{'endIndex': 492, 'startIndex': 483}]}}, {'mentionText': '15844.22\n', 'type': 'SS_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7730375528335571, 'y': 0.12263736128807068}, {'x': 0.8532423377037048, 'y': 0.12263736128807068}, {'x': 0.8532423377037048, 'y': 0.13318681716918945}, {'x': 0.7730375528335571, 'y': 0.13318681716918945}]}}]}, 'textAnchor': {'content': '15844.22\n', 'textSegments': [{'endIndex': 532, 'startIndex': 523}]}}, {'mentionText': '73-9506866\n', 'type': 'EM ...
# W2_XL_input_clean_2964
# downloaded
# Fetched file 8
# [{'mentionText': '191624.35\n', 'type': 'SS_WAGES', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5779294371604919, 'y': 0.5920879244804382}, {'x': 0.6666666865348816, 'y': 0.5920879244804382}, {'x': 0.6666666865348816, 'y': 0.6030769348144531}, {'x': 0.5779294371604919, 'y': 0.6030769348144531}]}}]}, 'textAnchor': {'content': '191624.35\n', 'textSegments': [{'endIndex': 2122, 'startIndex': 2112}]}}, {'mentionText': '246914.68\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5773606300354004, 'y': 0.565274715423584}, {'x': 0.6678043007850647, 'y': 0.565274715423584}, {'x': 0.6678043007850647, 'y': 0.5758242011070251}, {'x': 0.5773606300354004, 'y': 0.5758242011070251}]}}]}, 'textAnchor': {'content': '246914.68\n', 'textSegments': [{'endIndex': 2049, 'startIndex': 2039}]}}, {'mentionText': '14659.26\n', 'type': 'SS_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7736063599586487, 'y': 0.592527449131012}, {'x': 0.8526734709739685, 'y': 0.592527449131012}, {'x': 0.8526734709739685, 'y': 0.6030769348144531}, {'x': 0.7736063599586487, 'y': 0.6030769348144531}]}}]}, 'textAnchor': {'content': '14659.26\n', 'textSegments': [{'endIndex': 2131, 'startIndex': 2122}]}}, {'mentionText': '246914.68\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5773606300354004, 'y': 0.09406593441963196}, {'x': 0.6660978198051453, 'y': 0.09406593441963196}, {'x': 0.6660978198051453, 'y': 0.10417582094669342}, {'x': 0.5773606300354004, 'y': 0.10417582094669342}]}}]}, 'textAnchor': {'content': '246914.68\n', 'textSegments': [{'endIndex': 284, 'startIndex': 274}]}}, {'mentionText': '718-54-2653\n', 'type': 'EMPL_SSN', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.27303755283355713, 'y': 0.06681318581104279}, {'x': 0.3833902180194855, 'y': 0.06681318581104279}, {'x': 0.3833902180194855, 'y': 0.07692307978868484}, {'x': 0.27303755283355713, 'y': 0.07692307978868484}]}}]}, 'textAnchor': {'content': '718-54-2653\n', 'textSegments': [{'endIndex': 48, 'startIndex': 36}]}}, {'mentionText': '75406.1\n', 'type': 'FEDERAL_INCOME_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7758817076683044, 'y': 0.565274715423584}, {'x': 0.8435722589492798, 'y': 0.565274715423584}, {'x': 0.8435722589492798, 'y': 0.5758242011070251}, {'x': 0.7758817076683044, 'y': 0.5758242011070251}]}}]}, 'textAnchor': {'content': '75406.1\n', 'textSegments': [{'endIndex': 2057, 'startIndex': 2049}]}}, {'mentionText': 'Wheeler-Matthews PLC\n88391 Sarah Landing Suite 006\nAndrewbury TN 09526-1280\n', 'type': 'EMPLR_NAME_ADDRESS', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.08077360689640045, 'y': 0.12263736128807068}, {'x': 0.3782707750797272, 'y': 0.12263736128807068}, {'x': 0.3782707750797272, 'y': 0.17186813056468964}, {'x': 0.08077360689640045, 'y': 0.17186813056468964}]}}]}, 'textAnchor': {'content': 'Wheeler-Matthews PLC\n88391 Sarah Landing Suite 006\nAndrewbury TN 09526-1280\n', 'textSegments': [{'endIndex': 348, 'startIndex': 327}, {'endIndex': 405, 'startIndex': 350}]}}, {'mentionText': 'Wheeler-Matthews PLC\n88391 Sarah Landing Suite 006\nAndrewbury TN 09526-1280\n', 'type': 'EMPLR_NAME_ADDRESS', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.08077360689640045, 'y': 0.5929670333862305}, {'x': 0.3782707750797272, 'y': 0.5929670333862305}, {'x': 0.3782707750797272, 'y': 0.6426373720169067}, {'x': 0.08077360689640045, 'y': 0.6426373720169067}]}}]}, 'textAnchor': {'content': 'Wheeler-Matthews PLC\n88391 Sarah Landing Suite 006\nAndrewbury TN 09526-1280\n', 'textSegments': [{'endIndex': 1732, 'startIndex': 1711}, {'endIndex': 2420, 'startIndex': 2365}]}}, {'mentionText': '14659.26\n', 'type': 'SS_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertice ...
# W2_XL_input_clean_2965
# downloaded
# Fetched file 9
# [{'mentionText': '172465.27\n', 'type': 'SS_WAGES', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5762229561805725, 'y': 0.5929670333862305}, {'x': 0.6695107817649841, 'y': 0.5929670333862305}, {'x': 0.6695107817649841, 'y': 0.6030769348144531}, {'x': 0.5762229561805725, 'y': 0.6030769348144531}]}}]}, 'textAnchor': {'content': '172465.27\n', 'textSegments': [{'endIndex': 2219, 'startIndex': 2209}]}}, {'mentionText': '13193.59\n', 'type': 'SS_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7736063599586487, 'y': 0.592527449131012}, {'x': 0.8526734709739685, 'y': 0.592527449131012}, {'x': 0.8526734709739685, 'y': 0.6030769348144531}, {'x': 0.7736063599586487, 'y': 0.6030769348144531}]}}]}, 'textAnchor': {'content': '13193.59\n', 'textSegments': [{'endIndex': 2228, 'startIndex': 2219}]}}, {'mentionText': '133256.78\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5779294371604919, 'y': 0.565274715423584}, {'x': 0.6660978198051453, 'y': 0.565274715423584}, {'x': 0.6660978198051453, 'y': 0.5758242011070251}, {'x': 0.5779294371604919, 'y': 0.5758242011070251}]}}]}, 'textAnchor': {'content': '133256.78\n', 'textSegments': [{'endIndex': 2145, 'startIndex': 2135}]}}, {'mentionText': '13193.59\n', 'type': 'SS_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7724686861038208, 'y': 0.12263736128807068}, {'x': 0.8526734709739685, 'y': 0.12263736128807068}, {'x': 0.8526734709739685, 'y': 0.13274724781513214}, {'x': 0.7724686861038208, 'y': 0.13274724781513214}]}}]}, 'textAnchor': {'content': '13193.59\n', 'textSegments': [{'endIndex': 587, 'startIndex': 578}]}}, {'mentionText': '539-77-6027\n', 'type': 'EMPL_SSN', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.2690557539463043, 'y': 0.06681318581104279}, {'x': 0.38282138109207153, 'y': 0.06681318581104279}, {'x': 0.38282138109207153, 'y': 0.07692307978868484}, {'x': 0.2690557539463043, 'y': 0.07692307978868484}]}}]}, 'textAnchor': {'content': '539-77-6027\n', 'textSegments': [{'endIndex': 241, 'startIndex': 229}]}}, {'mentionText': '539-77-6027\n', 'type': 'EMPL_SSN', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.27076223492622375, 'y': 0.5375823974609375}, {'x': 0.3839590549468994, 'y': 0.5375823974609375}, {'x': 0.3839590549468994, 'y': 0.5485714077949524}, {'x': 0.27076223492622375, 'y': 0.5485714077949524}]}}]}, 'textAnchor': {'content': '539-77-6027\n', 'textSegments': [{'endIndex': 1652, 'startIndex': 1640}]}}, {'mentionText': '35018.34\n', 'type': 'FEDERAL_INCOME_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7730375528335571, 'y': 0.565274715423584}, {'x': 0.8532423377037048, 'y': 0.565274715423584}, {'x': 0.8532423377037048, 'y': 0.5758242011070251}, {'x': 0.7730375528335571, 'y': 0.5758242011070251}]}}]}, 'textAnchor': {'content': '35018.34\n', 'textSegments': [{'endIndex': 2154, 'startIndex': 2145}]}}, {'mentionText': 'Miller, Becker and Miller and Sons\n1322 Cynthia Isle Apt. 701\nPort Christian MD 01618-5114\n', 'type': 'EMPLR_NAME_ADDRESS', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.08304891735315323, 'y': 0.12219779938459396}, {'x': 0.4300341308116913, 'y': 0.12219779938459396}, {'x': 0.4300341308116913, 'y': 0.16967032849788666}, {'x': 0.08304891735315323, 'y': 0.16967032849788666}]}}]}, 'textAnchor': {'content': 'Miller, Becker and Miller and Sons\n1322 Cynthia Isle Apt. 701\nPort Christian MD 01618-5114\n', 'textSegments': [{'endIndex': 417, 'startIndex': 326}]}}, {'mentionText': '133256.78\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5779294371604919, 'y': 0.09362637251615524}, {'x': 0.6666666865348816, 'y': 0.09362637251615524}, {'x': 0.6666666865348816, 'y': 0.1037362664937973}, {'x': 0.5779294371604919 ...
# W2_XL_input_clean_2966
# downloaded
# Fetched file 10
# [{'mentionText': '177009.92\n', 'type': 'SS_WAGES', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5773606300354004, 'y': 0.592527449131012}, {'x': 0.6672354936599731, 'y': 0.592527449131012}, {'x': 0.6672354936599731, 'y': 0.6039560437202454}, {'x': 0.5773606300354004, 'y': 0.6039560437202454}]}}]}, 'textAnchor': {'content': '177009.92\n', 'textSegments': [{'endIndex': 2154, 'startIndex': 2144}]}}, {'mentionText': '13541.26\n', 'type': 'SS_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.774175226688385, 'y': 0.5920879244804382}, {'x': 0.8532423377037048, 'y': 0.5920879244804382}, {'x': 0.8532423377037048, 'y': 0.6030769348144531}, {'x': 0.774175226688385, 'y': 0.6030769348144531}]}}]}, 'textAnchor': {'content': '13541.26\n', 'textSegments': [{'endIndex': 2163, 'startIndex': 2154}]}}, {'mentionText': '162066.01\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5773606300354004, 'y': 0.565274715423584}, {'x': 0.6678043007850647, 'y': 0.565274715423584}, {'x': 0.6678043007850647, 'y': 0.5758242011070251}, {'x': 0.5773606300354004, 'y': 0.5758242011070251}]}}]}, 'textAnchor': {'content': '162066.01\n', 'textSegments': [{'endIndex': 2080, 'startIndex': 2070}]}}, {'mentionText': 'Horn, Freeman and Fuentes Inc\n39177 Nixon Mountains Suite 684\nMathisland\nRI\n11176-7653\n', 'type': 'EMPLR_NAME_ADDRESS', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.08191126585006714, 'y': 0.12263736128807068}, {'x': 0.3981797397136688, 'y': 0.12263736128807068}, {'x': 0.3981797397136688, 'y': 0.16967032849788666}, {'x': 0.08191126585006714, 'y': 0.16967032849788666}]}}]}, 'textAnchor': {'content': 'Horn, Freeman and Fuentes Inc\n39177 Nixon Mountains Suite 684\nMathisland\nRI\n11176-7653\n', 'textSegments': [{'endIndex': 260, 'startIndex': 198}, {'endIndex': 672, 'startIndex': 647}]}}, {'mentionText': '50844.75\n', 'type': 'FEDERAL_INCOME_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7718998789787292, 'y': 0.5648351907730103}, {'x': 0.8526734709739685, 'y': 0.5648351907730103}, {'x': 0.8526734709739685, 'y': 0.5758242011070251}, {'x': 0.7718998789787292, 'y': 0.5758242011070251}]}}]}, 'textAnchor': {'content': '50844.75\n', 'textSegments': [{'endIndex': 2089, 'startIndex': 2080}]}}, {'mentionText': 'Horn, Freeman and Fuentes Inc\n39177 Nixon Mountains Suite 684\nMathisland\nRI\n11176-7653\n', 'type': 'EMPLR_NAME_ADDRESS', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.08191126585006714, 'y': 0.5920879244804382}, {'x': 0.39874857664108276, 'y': 0.5920879244804382}, {'x': 0.39874857664108276, 'y': 0.6386812925338745}, {'x': 0.08191126585006714, 'y': 0.6386812925338745}]}}]}, 'textAnchor': {'content': 'Horn, Freeman and Fuentes Inc\n39177 Nixon Mountains Suite 684\nMathisland\nRI\n11176-7653\n', 'textSegments': [{'endIndex': 1763, 'startIndex': 1733}, {'endIndex': 2455, 'startIndex': 2398}]}}, {'mentionText': '351-91-6332\n', 'type': 'EMPL_SSN', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.2724687159061432, 'y': 0.5375823974609375}, {'x': 0.38282138109207153, 'y': 0.5375823974609375}, {'x': 0.38282138109207153, 'y': 0.5481318831443787}, {'x': 0.2724687159061432, 'y': 0.5481318831443787}]}}]}, 'textAnchor': {'content': '351-91-6332\n', 'textSegments': [{'endIndex': 1648, 'startIndex': 1636}]}}, {'mentionText': '162066.01\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5773606300354004, 'y': 0.09406593441963196}, {'x': 0.6678043007850647, 'y': 0.09406593441963196}, {'x': 0.6678043007850647, 'y': 0.10461538285017014}, {'x': 0.5773606300354004, 'y': 0.10461538285017014}]}}]}, 'textAnchor': {'content': '162066.01\n', 'textSegments': [{'endIndex': 528, 'startIndex': 518}]}}, {'mentionText': '13541.26\n', 'type': 'SS_TAX_WH', 'pageAnc ...
# W2_XL_input_clean_2967
# downloaded
# Fetched file 11
# [{'mentionText': '82885.75\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5767918229103088, 'y': 0.09362637251615524}, {'x': 0.6564277410507202, 'y': 0.09362637251615524}, {'x': 0.6564277410507202, 'y': 0.10417582094669342}, {'x': 0.5767918229103088, 'y': 0.10417582094669342}]}}]}, 'textAnchor': {'content': '82885.75\n', 'textSegments': [{'endIndex': 289, 'startIndex': 280}]}}, {'mentionText': '64989.22\n', 'type': 'SS_WAGES', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5773606300354004, 'y': 0.592527449131012}, {'x': 0.6581342220306396, 'y': 0.592527449131012}, {'x': 0.6581342220306396, 'y': 0.6030769348144531}, {'x': 0.5773606300354004, 'y': 0.6030769348144531}]}}]}, 'textAnchor': {'content': '64989.22\n', 'textSegments': [{'endIndex': 2133, 'startIndex': 2124}]}}, {'mentionText': '82885.75\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5762229561805725, 'y': 0.565274715423584}, {'x': 0.6569966077804565, 'y': 0.565274715423584}, {'x': 0.6569966077804565, 'y': 0.5758242011070251}, {'x': 0.5762229561805725, 'y': 0.5758242011070251}]}}]}, 'textAnchor': {'content': '82885.75\n', 'textSegments': [{'endIndex': 2061, 'startIndex': 2052}]}}, {'mentionText': '172-46-7966\n', 'type': 'EMPL_SSN', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.2701933979988098, 'y': 0.06681318581104279}, {'x': 0.3811149001121521, 'y': 0.06681318581104279}, {'x': 0.3811149001121521, 'y': 0.07692307978868484}, {'x': 0.2701933979988098, 'y': 0.07692307978868484}]}}]}, 'textAnchor': {'content': '172-46-7966\n', 'textSegments': [{'endIndex': 125, 'startIndex': 113}]}}, {'mentionText': '4971.68\n', 'type': 'SS_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7724686861038208, 'y': 0.592527449131012}, {'x': 0.8435722589492798, 'y': 0.592527449131012}, {'x': 0.8435722589492798, 'y': 0.6030769348144531}, {'x': 0.7724686861038208, 'y': 0.6030769348144531}]}}]}, 'textAnchor': {'content': '4971.68\n', 'textSegments': [{'endIndex': 2141, 'startIndex': 2133}]}}, {'mentionText': '4971.68\n', 'type': 'SS_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7718998789787292, 'y': 0.12263736128807068}, {'x': 0.8424345850944519, 'y': 0.12263736128807068}, {'x': 0.8424345850944519, 'y': 0.13274724781513214}, {'x': 0.7718998789787292, 'y': 0.13274724781513214}]}}]}, 'textAnchor': {'content': '4971.68\n', 'textSegments': [{'endIndex': 524, 'startIndex': 516}]}}, {'mentionText': 'Yoder-Young LLC\n9121 Bianca Drive\nDerekbury\nWV\n64170-9292\n', 'type': 'EMPLR_NAME_ADDRESS', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.08248008787631989, 'y': 0.12263736128807068}, {'x': 0.3566552996635437, 'y': 0.12263736128807068}, {'x': 0.3566552996635437, 'y': 0.17186813056468964}, {'x': 0.08248008787631989, 'y': 0.17186813056468964}]}}]}, 'textAnchor': {'content': 'Yoder-Young LLC\n9121 Bianca Drive\nDerekbury\nWV\n64170-9292\n', 'textSegments': [{'endIndex': 244, 'startIndex': 210}, {'endIndex': 669, 'startIndex': 645}]}}, {'mentionText': '172-46-7966\n', 'type': 'EMPL_SSN', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.2701933979988098, 'y': 0.5375823974609375}, {'x': 0.38282138109207153, 'y': 0.5375823974609375}, {'x': 0.38282138109207153, 'y': 0.5481318831443787}, {'x': 0.2701933979988098, 'y': 0.5481318831443787}]}}]}, 'textAnchor': {'content': '172-46-7966\n', 'textSegments': [{'endIndex': 1602, 'startIndex': 1590}]}}, {'mentionText': '9802.63\n', 'type': 'FEDERAL_INCOME_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7724686861038208, 'y': 0.565274715423584}, {'x': 0.8441410660743713, 'y': 0.565274715423584}, {'x': 0.8441410660743713, 'y': 0.5758242011070251}, {'x': 0.7724686861038208, 'y': 0.5758242011070251}]}}]}, 'text ...
# W2_XL_input_clean_2968
# downloaded
# Fetched file 12
# [{'mentionText': '286169.93\n', 'type': 'SS_WAGES', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5784983038902283, 'y': 0.5920879244804382}, {'x': 0.6678043007850647, 'y': 0.5920879244804382}, {'x': 0.6678043007850647, 'y': 0.6030769348144531}, {'x': 0.5784983038902283, 'y': 0.6030769348144531}]}}]}, 'textAnchor': {'content': '286169.93\n', 'textSegments': [{'endIndex': 2127, 'startIndex': 2117}]}}, {'mentionText': '244246.71\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5773606300354004, 'y': 0.565274715423584}, {'x': 0.6678043007850647, 'y': 0.565274715423584}, {'x': 0.6678043007850647, 'y': 0.5753846168518066}, {'x': 0.5773606300354004, 'y': 0.5753846168518066}]}}]}, 'textAnchor': {'content': '244246.71\n', 'textSegments': [{'endIndex': 2054, 'startIndex': 2044}]}}, {'mentionText': '21892.0\n', 'type': 'SS_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7736063599586487, 'y': 0.5929670333862305}, {'x': 0.8418657779693604, 'y': 0.5929670333862305}, {'x': 0.8418657779693604, 'y': 0.6026373505592346}, {'x': 0.7736063599586487, 'y': 0.6026373505592346}]}}]}, 'textAnchor': {'content': '21892.0\n', 'textSegments': [{'endIndex': 2135, 'startIndex': 2127}]}}, {'mentionText': '244246.71\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5784983038902283, 'y': 0.09406593441963196}, {'x': 0.6672354936599731, 'y': 0.09406593441963196}, {'x': 0.6672354936599731, 'y': 0.10505493730306625}, {'x': 0.5784983038902283, 'y': 0.10505493730306625}]}}]}, 'textAnchor': {'content': '244246.71\n', 'textSegments': [{'endIndex': 344, 'startIndex': 334}]}}, {'mentionText': 'Turner-Michael Inc\n3541 Jennifer Shores Suite 202\nMichellechester\nDE\n13284-4139\n', 'type': 'EMPLR_NAME_ADDRESS', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.08191126585006714, 'y': 0.12263736128807068}, {'x': 0.4391353726387024, 'y': 0.12263736128807068}, {'x': 0.4391353726387024, 'y': 0.17010988295078278}, {'x': 0.08191126585006714, 'y': 0.17010988295078278}]}}]}, 'textAnchor': {'content': 'Turner-Michael Inc\n3541 Jennifer Shores Suite 202\nMichellechester\nDE\n13284-4139\n', 'textSegments': [{'endIndex': 256, 'startIndex': 237}, {'endIndex': 500, 'startIndex': 469}, {'endIndex': 667, 'startIndex': 637}]}}, {'mentionText': '150-46-5585\n', 'type': 'EMPL_SSN', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.27189987897872925, 'y': 0.5371428728103638}, {'x': 0.38282138109207153, 'y': 0.5371428728103638}, {'x': 0.38282138109207153, 'y': 0.5476922988891602}, {'x': 0.27189987897872925, 'y': 0.5476922988891602}]}}]}, 'textAnchor': {'content': '150-46-5585\n', 'textSegments': [{'endIndex': 1633, 'startIndex': 1621}]}}, {'mentionText': 'Turner-Michael Inc\n3541 Jennifer Shores Suite 202\nMichellechester\nDE\n13284-4139\n', 'type': 'EMPLR_NAME_ADDRESS', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.08248008787631989, 'y': 0.592527449131012}, {'x': 0.4391353726387024, 'y': 0.592527449131012}, {'x': 0.4391353726387024, 'y': 0.639120876789093}, {'x': 0.08248008787631989, 'y': 0.639120876789093}]}}]}, 'textAnchor': {'content': 'Turner-Michael Inc\n3541 Jennifer Shores Suite 202\nMichellechester\nDE\n13284-4139\n', 'textSegments': [{'endIndex': 1737, 'startIndex': 1718}, {'endIndex': 2431, 'startIndex': 2370}]}}, {'mentionText': '286169.93\n', 'type': 'SS_WAGES', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5779294371604919, 'y': 0.12263736128807068}, {'x': 0.6678043007850647, 'y': 0.12263736128807068}, {'x': 0.6678043007850647, 'y': 0.13406594097614288}, {'x': 0.5779294371604919, 'y': 0.13406594097614288}]}}]}, 'textAnchor': {'content': '286169.93\n', 'textSegments': [{'endIndex': 378, 'startIndex': 368}]}}, {'mentionText': '150-46-5585\n', 'type': 'EMPL_SSN', 'pageAn ...
# W2_XL_input_clean_2969
# downloaded
# Fetched file 13
# ...
# W2_XL_input_clean_2958
# downloaded
# Fetched file 49
# [{'mentionText': '202731.9\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5773606300354004, 'y': 0.09362637251615524}, {'x': 0.6558589339256287, 'y': 0.09362637251615524}, {'x': 0.6558589339256287, 'y': 0.1037362664937973}, {'x': 0.5773606300354004, 'y': 0.1037362664937973}]}}]}, 'textAnchor': {'content': '202731.9\n', 'textSegments': [{'endIndex': 172, 'startIndex': 163}]}}, {'mentionText': '184282.99\n', 'type': 'SS_WAGES', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5779294371604919, 'y': 0.592527449131012}, {'x': 0.6672354936599731, 'y': 0.592527449131012}, {'x': 0.6672354936599731, 'y': 0.6030769348144531}, {'x': 0.5779294371604919, 'y': 0.6030769348144531}]}}]}, 'textAnchor': {'content': '184282.99\n', 'textSegments': [{'endIndex': 2201, 'startIndex': 2191}]}}, {'mentionText': '14097.65\n', 'type': 'SS_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7724686861038208, 'y': 0.592527449131012}, {'x': 0.8532423377037048, 'y': 0.592527449131012}, {'x': 0.8532423377037048, 'y': 0.6030769348144531}, {'x': 0.7724686861038208, 'y': 0.6030769348144531}]}}]}, 'textAnchor': {'content': '14097.65\n', 'textSegments': [{'endIndex': 2210, 'startIndex': 2201}]}}, {'mentionText': '202731.9\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5779294371604919, 'y': 0.565274715423584}, {'x': 0.6575654149055481, 'y': 0.565274715423584}, {'x': 0.6575654149055481, 'y': 0.5762637257575989}, {'x': 0.5779294371604919, 'y': 0.5762637257575989}]}}]}, 'textAnchor': {'content': '202731.9\n', 'textSegments': [{'endIndex': 2127, 'startIndex': 2118}]}}, {'mentionText': '312-65-0878\n', 'type': 'EMPL_SSN', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.27076223492622375, 'y': 0.06681318581104279}, {'x': 0.3811149001121521, 'y': 0.06681318581104279}, {'x': 0.3811149001121521, 'y': 0.07692307978868484}, {'x': 0.27076223492622375, 'y': 0.07692307978868484}]}}]}, 'textAnchor': {'content': '312-65-0878\n', 'textSegments': [{'endIndex': 239, 'startIndex': 227}]}}, {'mentionText': '184282.99\n', 'type': 'SS_WAGES', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5773606300354004, 'y': 0.12263736128807068}, {'x': 0.6672354936599731, 'y': 0.12263736128807068}, {'x': 0.6672354936599731, 'y': 0.13318681716918945}, {'x': 0.5773606300354004, 'y': 0.13318681716918945}]}}]}, 'textAnchor': {'content': '184282.99\n', 'textSegments': [{'endIndex': 447, 'startIndex': 437}]}}, {'mentionText': '66046.06\n', 'type': 'FEDERAL_INCOME_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7724686861038208, 'y': 0.565274715423584}, {'x': 0.8515358567237854, 'y': 0.565274715423584}, {'x': 0.8515358567237854, 'y': 0.5758242011070251}, {'x': 0.7724686861038208, 'y': 0.5758242011070251}]}}]}, 'textAnchor': {'content': '66046.06\n', 'textSegments': [{'endIndex': 2136, 'startIndex': 2127}]}}, {'mentionText': '14097.65\n', 'type': 'SS_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7718998789787292, 'y': 0.12219779938459396}, {'x': 0.852104663848877, 'y': 0.12219779938459396}, {'x': 0.852104663848877, 'y': 0.13230769336223602}, {'x': 0.7718998789787292, 'y': 0.13230769336223602}]}}]}, 'textAnchor': {'content': '14097.65\n', 'textSegments': [{'endIndex': 580, 'startIndex': 571}]}}, {'mentionText': '312-65-0878\n', 'type': 'EMPL_SSN', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.2724687159061432, 'y': 0.5375823974609375}, {'x': 0.38225257396698, 'y': 0.5375823974609375}, {'x': 0.38225257396698, 'y': 0.5485714077949524}, {'x': 0.2724687159061432, 'y': 0.5485714077949524}]}}]}, 'textAnchor': {'content': '312-65-0878\n', 'textSegments': [{'endIndex': 1639, 'startIndex': 1627}]}}, {'mentionText': '66046.06\n', 'type': 'FEDERAL_INCOME_TAX_WH ...
# W2_XL_input_clean_2959
# downloaded
# Fetched file 50
# [{'mentionText': '218533.71\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5773606300354004, 'y': 0.09362637251615524}, {'x': 0.6678043007850647, 'y': 0.09362637251615524}, {'x': 0.6678043007850647, 'y': 0.1037362664937973}, {'x': 0.5773606300354004, 'y': 0.1037362664937973}]}}]}, 'textAnchor': {'content': '218533.71\n', 'textSegments': [{'endIndex': 144, 'startIndex': 134}]}}, {'mentionText': '254440.14\n', 'type': 'SS_WAGES', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5779294371604919, 'y': 0.592527449131012}, {'x': 0.6666666865348816, 'y': 0.592527449131012}, {'x': 0.6666666865348816, 'y': 0.6030769348144531}, {'x': 0.5779294371604919, 'y': 0.6030769348144531}]}}]}, 'textAnchor': {'content': '254440.14\n', 'textSegments': [{'endIndex': 2126, 'startIndex': 2116}]}}, {'mentionText': '19464.67\n', 'type': 'SS_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7724686861038208, 'y': 0.592527449131012}, {'x': 0.8555176258087158, 'y': 0.592527449131012}, {'x': 0.8555176258087158, 'y': 0.6030769348144531}, {'x': 0.7724686861038208, 'y': 0.6030769348144531}]}}]}, 'textAnchor': {'content': '19464.67\n', 'textSegments': [{'endIndex': 2135, 'startIndex': 2126}]}}, {'mentionText': 'Singh-Smith Inc\n470 James Forks\nNorth Taylor\nOR\n88458-1903\n', 'type': 'EMPLR_NAME_ADDRESS', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.08304891735315323, 'y': 0.12131868302822113}, {'x': 0.3788395822048187, 'y': 0.12131868302822113}, {'x': 0.3788395822048187, 'y': 0.17186813056468964}, {'x': 0.08304891735315323, 'y': 0.17186813056468964}]}}]}, 'textAnchor': {'content': 'Singh-Smith Inc\n470 James Forks\nNorth Taylor\nOR\n88458-1903\n', 'textSegments': [{'endIndex': 358, 'startIndex': 326}, {'endIndex': 506, 'startIndex': 479}]}}, {'mentionText': '218533.71\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5779294371604919, 'y': 0.565274715423584}, {'x': 0.6678043007850647, 'y': 0.565274715423584}, {'x': 0.6678043007850647, 'y': 0.5758242011070251}, {'x': 0.5779294371604919, 'y': 0.5758242011070251}]}}]}, 'textAnchor': {'content': '218533.71\n', 'textSegments': [{'endIndex': 2052, 'startIndex': 2042}]}}, {'mentionText': '32346.88\n', 'type': 'FEDERAL_INCOME_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7736063599586487, 'y': 0.565274715423584}, {'x': 0.8532423377037048, 'y': 0.565274715423584}, {'x': 0.8532423377037048, 'y': 0.5758242011070251}, {'x': 0.7736063599586487, 'y': 0.5758242011070251}]}}]}, 'textAnchor': {'content': '32346.88\n', 'textSegments': [{'endIndex': 2061, 'startIndex': 2052}]}}, {'mentionText': '849-97-6421\n', 'type': 'EMPL_SSN', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.2701933979988098, 'y': 0.06681318581104279}, {'x': 0.38225257396698, 'y': 0.06681318581104279}, {'x': 0.38225257396698, 'y': 0.07692307978868484}, {'x': 0.2701933979988098, 'y': 0.07692307978868484}]}}]}, 'textAnchor': {'content': '849-97-6421\n', 'textSegments': [{'endIndex': 241, 'startIndex': 229}]}}, {'mentionText': 'Singh-Smith Inc\n470 James Forks\nNorth Taylor\nOR\n88458-1903\n', 'type': 'EMPLR_NAME_ADDRESS', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.08191126585006714, 'y': 0.591208815574646}, {'x': 0.3788395822048187, 'y': 0.591208815574646}, {'x': 0.3788395822048187, 'y': 0.6421977877616882}, {'x': 0.08191126585006714, 'y': 0.6421977877616882}]}}]}, 'textAnchor': {'content': 'Singh-Smith Inc\n470 James Forks\nNorth Taylor\nOR\n88458-1903\n', 'textSegments': [{'endIndex': 1735, 'startIndex': 1703}, {'endIndex': 2397, 'startIndex': 2370}]}}, {'mentionText': '849-97-6421\n', 'type': 'EMPL_SSN', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.2701933979988098, 'y': 0.5375823974609375}, {'x': 0.3 ...
# W2_XL_input_clean_2999
# downloaded
# Fetched file 51
# [{'mentionText': '91282.31\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5767918229103088, 'y': 0.565274715423584}, {'x': 0.6558589339256287, 'y': 0.565274715423584}, {'x': 0.6558589339256287, 'y': 0.5758242011070251}, {'x': 0.5767918229103088, 'y': 0.5758242011070251}]}}]}, 'textAnchor': {'content': '91282.31\n', 'textSegments': [{'endIndex': 2065, 'startIndex': 2056}]}}, {'mentionText': '97402.36\n', 'type': 'SS_WAGES', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5762229561805725, 'y': 0.592527449131012}, {'x': 0.6564277410507202, 'y': 0.592527449131012}, {'x': 0.6564277410507202, 'y': 0.6030769348144531}, {'x': 0.5762229561805725, 'y': 0.6030769348144531}]}}]}, 'textAnchor': {'content': '97402.36\n', 'textSegments': [{'endIndex': 2138, 'startIndex': 2129}]}}, {'mentionText': '7451.28\n', 'type': 'SS_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7753128409385681, 'y': 0.592527449131012}, {'x': 0.8418657779693604, 'y': 0.592527449131012}, {'x': 0.8418657779693604, 'y': 0.6026373505592346}, {'x': 0.7753128409385681, 'y': 0.6026373505592346}]}}]}, 'textAnchor': {'content': '7451.28\n', 'textSegments': [{'endIndex': 2146, 'startIndex': 2138}]}}, {'mentionText': '91282.31\n', 'type': 'WAGES_TIPS_OTHER_COMP', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.5779294371604919, 'y': 0.09362637251615524}, {'x': 0.6564277410507202, 'y': 0.09362637251615524}, {'x': 0.6564277410507202, 'y': 0.10417582094669342}, {'x': 0.5779294371604919, 'y': 0.10417582094669342}]}}]}, 'textAnchor': {'content': '91282.31\n', 'textSegments': [{'endIndex': 301, 'startIndex': 292}]}}, {'mentionText': '522-86-4190\n', 'type': 'EMPL_SSN', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.2701933979988098, 'y': 0.06637362390756607}, {'x': 0.38168373703956604, 'y': 0.06637362390756607}, {'x': 0.38168373703956604, 'y': 0.07736263424158096}, {'x': 0.2701933979988098, 'y': 0.07736263424158096}]}}]}, 'textAnchor': {'content': '522-86-4190\n', 'textSegments': [{'endIndex': 67, 'startIndex': 55}]}}, {'mentionText': '7451.28\n', 'type': 'SS_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7736063599586487, 'y': 0.12263736128807068}, {'x': 0.8418657779693604, 'y': 0.12263736128807068}, {'x': 0.8418657779693604, 'y': 0.13274724781513214}, {'x': 0.7736063599586487, 'y': 0.13274724781513214}]}}]}, 'textAnchor': {'content': '7451.28\n', 'textSegments': [{'endIndex': 557, 'startIndex': 549}]}}, {'mentionText': 'Hall Ltd Group\n1860 Cynthia Harbor\nWest Chelsea LA 84582-8152\n', 'type': 'EMPLR_NAME_ADDRESS', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.08077360689640045, 'y': 0.591208815574646}, {'x': 0.3885096609592438, 'y': 0.591208815574646}, {'x': 0.3885096609592438, 'y': 0.639120876789093}, {'x': 0.08077360689640045, 'y': 0.639120876789093}]}}]}, 'textAnchor': {'content': 'Hall Ltd Group\n1860 Cynthia Harbor\nWest Chelsea LA 84582-8152\n', 'textSegments': [{'endIndex': 1749, 'startIndex': 1687}]}}, {'mentionText': '31479.62\n', 'type': 'FEDERAL_INCOME_TAX_WH', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.7736063599586487, 'y': 0.5648351907730103}, {'x': 0.8543799519538879, 'y': 0.5648351907730103}, {'x': 0.8543799519538879, 'y': 0.5758242011070251}, {'x': 0.7736063599586487, 'y': 0.5758242011070251}]}}]}, 'textAnchor': {'content': '31479.62\n', 'textSegments': [{'endIndex': 2074, 'startIndex': 2065}]}}, {'mentionText': 'Hall Ltd Group\n1860 Cynthia Harbor\nWest Chelsea LA 84582-8152\n', 'type': 'EMPLR_NAME_ADDRESS', 'pageAnchor': {'pageRefs': [{'boundingPoly': {'normalizedVertices': [{'x': 0.08077360689640045, 'y': 0.12175823748111725}, {'x': 0.3902161419391632, 'y': 0.12175823748111725}, {'x': 0.3902161419391632, 'y': 0.16967032849788666}, {'x': 0.08077360689640045, 'y': 0.1696 ...
